# %% [markdown]
# # Blueberry winery EDA  (/winequality-red.csv)

# %%
import numpy as np 
import pandas as pd

# The two libraries we are are using for EDA
import matplotlib.pyplot as plt 
import seaborn as sns

#red_wine = pd.read_csv('C:\Users\sfmol\Dropbox\CAB\VSCode_GitHub\blueberry_winerys_project\winequality-red.csv')
#red_wine = pd.read_csv('C:\\Users\\sfmol\\Dropbox\\CAB\\VSCode_GitHub\\blueberry_winerys_project\\winequality-red.csv')
#red_wine = pd.read_csv('C:/Users/sfmol/Dropbox/CAB/VSCode_GitHub/blueberry_winerys_project/winequality-red.csv')
#red_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv')

# %% [markdown]
# ## Load datasets and defining Data Frames

# %%
red_wine = pd.read_csv('winequality-red.csv', sep=';')

white_wine = pd.read_csv('winequality-white.csv', sep=';')

# %%
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## Data Wrangling

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
# Imprimir los primeros 10 registros
red_wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# Imprimir los últimos 10 registros
red_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# Mostrar la forma del DataFrame
red_wine.shape
# Out:
# (1599, 12)

# %%
# Para observar si hay valores faltantes o nulos en tu DataFrame en pandas, puedes usar los métodos isna() o isnull(). Ambos métodos son equivalentes y devuelven una matriz booleana con el mismo tamaño que el DataFrame original, donde cada valor es True si es un valor faltante y False de lo contrario.

# Para observar si hay valores faltantes
red_wine.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
# Para observar si hay valores nulos:
red_wine.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %% [markdown]
# El resultado será una matriz booleana con True en las celdas donde hay valores faltantes y False en las celdas donde no hay valores faltantes. Puedes sumar los valores True de cada columna para obtener el número total de valores faltantes en esa columna:

# %%
# Obtener el número de valores faltantes por columna
red_wine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Obtener el número de valores nulos por columna
red_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Este código devolverá una serie que muestra el número de valores faltantes en cada columna. Si el número es cero, significa que no hay valores faltantes en esa columna.

# %% [markdown]
# ### White Wine Dataset

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# Obtener estadísticas descriptivas para el conjunto de datos de vino blanco
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
#Corrigiendo el error del ";" como Killian:

#white_wine = pd.read_csv('winequality-white.csv', sep=';')

# %%
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ### Transforming the quality_label column into categorical data type

# %%
# para crear la nueva columna quality_label en el DataFrame red_wine, usando la columna quality existente y la función lambda especificada:

red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low' if value <= 5 else 'medium' if value <= 7 else 'high')

# %%
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low' if value <= 5 else 'medium' if value <= 7 else 'high')

# %% [markdown]
# This code creates a new column called "quality_label" in the "red_wine" DataFrame and assigns values based on the "quality" column. The lambda function takes each value from the "quality" column, compares it with a series of conditions, and returns a quality label ('low', 'medium', or 'high') for that value. Then, the "quality_label" column is filled with these corresponding quality labels.

# %%
display(red_wine.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label
# 0      9.4        5           low
# ...

# %%
display(white_wine.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality quality_label
# 0      8.8        6        medium
# ...

# %%
# Statistical parameters for only the 'alcohol' column in the 'red_wine' DataFrame:

red_wine.describe()['alcohol']
# Out:
# count    1599.000000
# mean       10.422983
# std         1.065668
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %% [markdown]
# The 'include' parameter in the 'describe()' method only accepts data type values, not specific column names. If you want to obtain descriptive statistics for a specific column, you can use specific methods for that column, such as 'mean()' for the mean or 'std()' for the standard deviation.
#
# For example, to obtain the mean and standard deviation of the 'alcohol' column, you can use the following:

# %%
print("Mean of the 'alcohol' column:", red_wine['alcohol'].mean())
print("Standard Deviation 'alcohol'column:", red_wine['alcohol'].std())
# Out:
# Mean of the 'alcohol' column: 10.422983114446529
# Standard Deviation 'alcohol'column: 1.0656675818473946

# %%
# "To display the names of all columns in Pandas:"

red_wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'quality_label'],
#       dtype='object')

# %% [markdown]
# ### Describing both databases at once horizontally

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %% [markdown]
# ### Describing both databases at once vertically

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=0, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#                          fixed acidity  volatile acidity  citric acid  \
# Red Wines Stats   count    1599.000000       1599.000000  1599.000000
#                   mean        8.319637          0.527821     0.270976
#                   std         1.741096          0.179060     0.194801
#                   min         4.600000          0.120000     0.000000
#                   25%         7.100000          0.390000     0.090000
#                   50%         7.900000          0.520000     0.260000
#                   75%         9.200000          0.640000     0.420000
#                   max        15.900000          1.580000     1.000000
# White Wines Stats count    4898.000000       4898.000000  4898.000000
#                   mean        6.854788          0.278241     0.334192
#                   std         0.843868          0.100795     0.121020
#                   min         3.800000          0.080000     0.000000
# ...

# %% [markdown]
# ### Summary of some entries

# %%
## cargar los conjuntos de datos de vino rojo y blanco
# red_wine = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')
# white_wine = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", sep=';')

## crear una nueva columna para etiquetar la calidad del vino
# red_wine['quality_label'] = pd.cut(red_wine['quality'], bins=[0, 5, 7, 10], labels=['low', 'medium', 'high'])
# white_wine['quality_label'] = pd.cut(white_wine['quality'], bins=[0, 5, 7, 10], labels=['low', 'medium', 'high'])

## transformar las etiquetas en tipo de datos categóricos
# red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'], categories=['low', 'medium', 'high'])
# white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'], categories=['low', 'medium', 'high'])

## concatenar las estadísticas descriptivas de los conjuntos de datos de vino rojo y blanco
# wine_stats = pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# print(wine_stats)

# %% [markdown]
# # Plotting

# %%
sns.boxplot(data=red_wine, x=red_wine['fixed acidity'])
plt.xlabel('fixed acidity')
plt.show()

# %%
sns.histplot(data=red_wine,x='quality')
plt.show()

# %% [markdown]
# ##### To make a pie chart, showing the quantity of red wines compared to the quantity of white wines. This will create a pie chart that shows the percentage of red wines compared to white wines in your dataset. The autopct argument formats the values as percentages with one decimal place. You can adjust the formatting as needed.

# %%
# count the number of red and white wines
red_count = len(red_wine)
white_count = len(white_wine)

# %%
# create a list of values and labels for the pie chart
values = [red_count, white_count]
labels = ['Red Wine', 'White Wine']

# %%
# create the pie chart
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.title('Red Wine vs. White Wine',fontsize=15)

# Define the colors for the pie chart
colors = ['#FF4136', '#3D9970']

# Set the label font size
plt.legend(labels, loc="best", fontsize=8)


plt.show()

# %% [markdown]
# #### To show the distribution of qualities

# %%
#Using the seaborn library to create a histogram for the quality distribution in red wines (This will create a histogram with the quality values on the x-axis and the count on the y-axis, with 6 bins and a kernel density estimate (KDE) curve overlaid. You can adjust the bins parameter to change the number of bins, and set kde=False to remove the KDE curve if you prefer. You can also adjust the data and x parameters to create a histogram for the quality distribution in white wines or other columns in the dataset):


sns.histplot(data=red_wine, x='quality', bins=6, kde=True)
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
# Module1_Project2_Sprint1: "Try using the seaborn histplot.You have to make sure that both plots have the same order in the X-Axys.Once you manage to create it, try playing with the colors and the titles too.Now try to compare the quality with some other features"


# Set style and context for the plot
sns.set_style('whitegrid')
sns.set_context('talk')

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6), sharey=True)

# Plot histograms of wine quality for red and white wines
sns.histplot(ax=axes[0], data=red_wine, x='quality', bins=6, color='darkred', alpha=0.8)
sns.histplot(ax=axes[1], data=white_wine, x='quality', bins=6, color='darkgreen', alpha=0.8)

# Set x and y axis labels
axes[0].set_xlabel('Quality')
axes[0].set_ylabel('Count')
axes[1].set_xlabel('Quality')

# Set titles for the subplots
axes[0].set_title('Red Wine Quality Distribution')
axes[1].set_title('White Wine Quality Distribution')

# Show the plot
plt.show()

# %%
sns.histplot(data=red_wine, x='pH', hue='quality_label', bins=20, palette=['#FFC107', '#FF5733', '#C70039'])
plt.title('Distribution of pH Value by Wine Quality', fontsize=14, fontweight='bold')
plt.xlabel('pH Value', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Quality', fontsize=10)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
red_wine = pd.concat([red_wine, white_wine], axis=0)
sns.boxplot(x='fixed acidity', y='alcohol', data=red_wine)
plt.title('Distribution of Alcohol Content by Fixed Acidity')
plt.xlabel('Fixed Acidity')
plt.ylabel('Alcohol Content (%)')
plt.show()

# %% [markdown]
# ### **How to fix the plot scale? Why is the graph cut off?

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(10, 9))
sns.boxplot(x='fixed acidity', y='alcohol', data=red_wine, ax=ax)
ax.set_ylim(0, 20)
ax.set_xlim(0, 30)
plt.title('Distribution of Alcohol Content by Fixed Acidity')
plt.xlabel('Fixed Acidity')
plt.ylabel('Alcohol Content (%)')
plt.show()

# %%
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine = pd.concat([red_wine, white_wine], axis=0)
sns.boxplot(x='residual sugar', y='fixed acidity', data=red_wine, orient='h')
plt.title('Distribution of Residual Sugar by Fixed Acidity')
plt.xlabel('Residual Sugar (g/dm^3)')
plt.ylabel('Fixed Acidity')
plt.show()

# %%
red_wine.describe()['residual sugar']
# Out:
# count    11395.000000
# mean         5.850799
# std          4.917592
# min          0.600000
# 25%          1.800000
# 50%          4.100000
# 75%          8.800000
# max         65.800000
# Name: residual sugar, dtype: float64

# %%
red_wine.describe()['fixed acidity']
# Out:
# count    11395.000000
# mean         7.060342
# std          1.138484
# min          3.800000
# 25%          6.400000
# 50%          6.900000
# 75%          7.500000
# max         15.900000
# Name: fixed acidity, dtype: float64

# %%
sns.set_style('whitegrid')
sns.set_palette("husl")
fig, ax = plt.subplots(figsize=(25, 18))
ax.set_ylim(0, 18)
ax.set_xlim(0, 18)
red_wine = pd.concat([red_wine], axis=0)
sns.boxplot(x='residual sugar', y='fixed acidity', data=red_wine, orient='h')
plt.title('Distribution of Fixed Acidity by Residual Sugar')
plt.xlabel('Residual Sugar (g/dm^3)')
plt.ylabel('Fixed Acidity', fontsize=28)
plt.show()

# %% [markdown]
# ## Improving the chart with Killian (claening the outliers + improving format)

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(25, 18))
ax.set_ylim(0, 18)
ax.set_xlim(0, 23)
red_wine = pd.concat([red_wine], axis=0)
sns.boxplot(x='residual sugar', y='fixed acidity', data=red_wine, orient='h', showfliers=False)
plt.title('Distribution of Fixed Acidity by Residual Sugar')
plt.xlabel('Residual Sugar (g/dm^3)')
plt.ylabel('Fixed Acidity')
plt.tight_layout()
plt.show()

# %%
red_wine.hist(bins=15, color='darkred', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
white_wine.hist(bins=15, color='green', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %% [markdown]
# Seaborn library in Python to create a histogram plot of the variables in the "white_wine" dataset. ...What each of the arguments is doing:
#
# bins=15: This sets the number of bins or bars in the histogram to 15.
# color='green': This sets the color of the bars in the histogram to green.
# edgecolor='black': This sets the color of the edges of the bars to black.
# linewidth=1.0: This sets the width of the bar edges to 1.0.
# xlabelsize=8: This sets the size of the x-axis label to 8.
# ylabelsize=8: This sets the size of the y-axis label to 8.
# grid=False: This turns off the gridlines in the plot.
# plt.tight_layout(rect=(0, 0, 1.2, 1.2)) is a function that automatically adjusts the subplot parameters to make sure the subplot(s) fits in to the figure area. It takes in a rectangle tuple (left, bottom, right, top) as argument to define the subplots layout.
#
# rt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15) creates a super title for the subplots (i.e. the entire figure) with a font size of 15, and position x=0.65 and y=1.25 (in relative figure coordinates).
#
# Overall, this code is creating a histogram plot for the "white_wine" dataset with some specific visual attributes, and is also adjusting the subplot layout and adding a super title to the plot.

# %% [markdown]
# # *Repair

# %%
# Set style and context for the plot
sns.set_style('whitegrid')
sns.set_context('talk')

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6), sharey=True)

# Plot histograms of wine volatile acidity for red and white wines
sns.histplot(ax=axes[0], data=red_wine, x='volatile acidity', bins=6, color='darkred', alpha=0.8)
sns.histplot(ax=axes[1], data=white_wine, x='volatile acidity', bins=6, color='green', alpha=0.8)

# Set x and y axis labels
axes[0].set_xlabel('volatile acidity')
axes[0].set_ylabel('Count')
axes[1].set_xlabel('volatile acidity')

# Set titles for the subplots
axes[0].set_title('Red Wine volatile acidity Distribution')
axes[1].set_title('White Wine volatile acidity Distribution')

# Show the plot
plt.show()

# %%
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# <center><h4>Seaborn Implot</h4></center>

# %%
sns.lmplot(data=red_wine, x='fixed acidity', y='quality')
plt.title('Fixed Acidity vs Quality')
plt.xlabel('Fixed Acidity')
plt.ylabel('Quality')
# Out:
# Text(69.125, 0.5, 'Quality')

# %%
sns.lmplot(data=white_wine, x='fixed acidity', y='quality')
plt.title('Fixed Acidity vs Quality')
plt.xlabel('Fixed Acidity')
plt.ylabel('Quality')
# Out:
# Text(69.125, 0.5, 'Quality')

# %%
sns.scatterplot(data=white_wine, x='fixed acidity', y='quality')
plt.title('Fixed Acidity vs Quality')
plt.xlabel('Fixed Acidity')
plt.ylabel('Quality')
# Out:
# Text(0, 0.5, 'Quality')

# %%
red_wine.hist(bins=15, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
red_sdf = red_wine[['sulphates', 'alcohol', 'quality']]
red_sdf.head()
corrred = red_sdf.corr()
sns.heatmap(corrred)
# Out:
# <Axes: >

# %%
sns.heatmap(corrred, cmap='RdBu')
# Out:
# <Axes: >

# %%
sns.heatmap(corrred, cmap='RdBu', vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
sns.heatmap(corrred, cmap='RdBu', vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(corrred, cmap='RdBu', vmin=-1, vmax=1, annot=True, 
            annot_kws={'fontsize':11, 'fontweight':'bold'})
# Out:
# <Axes: >

# %%
sns.heatmap(corrred, cmap='RdBu', vmin=-1, vmax=1, annot=True, 
            annot_kws={'fontsize':11, 'fontweight':'bold'},
           square=True)
# Out:
# <Axes: >

# %%
sns.heatmap(corrred, cmap='RdBu', vmin=-1, vmax=1, annot=True, 
            annot_kws={'fontsize':11, 'fontweight':'bold'},
           square=True)
sns.set(rc = {'figure.figsize':(15,8)})

# %% [markdown]
# ### Red_wine specific dataframe2

# %% [markdown]
# ### Red_wine specific dataframe2 - Color

# %%
red_sdf2 = red_wine[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']]

corrred = red_sdf2.corr()

sns.heatmap(corrred, vmin=-1, vmax=1, annot=True, 
            annot_kws={'fontsize':11, 'fontweight':'bold'},
           square=True)
sns.set(rc = {'figure.figsize':(15,8)})

# %%
red_sdf2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # White Wine

# %%
white_sdf2 = white_wine[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']]

corrwhite = white_sdf2.corr()

sns.heatmap(corrwhite, cmap='Greens', vmin=-1, vmax=1, annot=True, 
            annot_kws={'fontsize':11, 'fontweight':'bold'},
            square=True)

sns.set(rc={'figure.figsize':(15,8)})

# %% [markdown]
# ## *(not useful in the pre-presentation) Combining Red and White wines datasets into one

# %%
# Combine the two datasets into one
red_wine = pd.concat([red_wine, white_wine], axis=0)

# Create a correlation matrix for all variables
corrred = red_wine.corr()

# Create a heatmap for the correlation matrix
sns.heatmap(corrred, xticklabels=corrred.columns.values, yticklabels=corrred.columns.values)

sns.heatmap(corrred, vmin=-1, vmax=1, annot=True, 
            annot_kws={'fontsize':11, 'fontweight':'bold'},
           square=True)
sns.set(rc = {'figure.figsize':(15,8)})


# Set the title of the plot
plt.title('Correlation Heatmap for Wine Quality Variables')
# Out:
# C:\Users\sfmol\AppData\Local\Temp\ipykernel_18864\1759818086.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrred = red_wine.corr()
# Text(0.5, 1.0, 'Correlation Heatmap for Wine Quality Variables')

# %% [markdown]
# ## *(not useful) Combining Red and White wines datasets into oneTaking out the "cbar"

# %%
sns.heatmap(corrred, vmin=-1, vmax=1, annot=True, 
            annot_kws={'fontsize':11, 'fontweight':'bold'},
            square=True, cbar=False)

sns.set(rc = {'figure.figsize':(15,8)})

# %% [markdown]
# # Scatterplot - Both types of wine

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, gridspec_kw={'width_ratios': [1, 1]})

# Create the first scatterplot for the red wine dataset
sns.scatterplot(data=red_wine, x='alcohol', y='quality', ax=ax1, color='r')
ax1.set_title('Red Wine Quality Variables')

# Create the second scatterplot for the white wine dataset
sns.scatterplot(data=white_wine, x='alcohol', y='quality', ax=ax2, color='g')
ax2.set_title('White Wine Quality Variables')

# Set the figure title
fig.suptitle('Scatterplots for Alcohol vs Quality in Wine Datasets', fontsize=16)

# Adjust the layout to prevent overlapping
fig.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## To review

# %%
rw = red_wine
corrred = rw.corr()
f,ax = plt.subplots(figsize=(15,12))
mask = np.zeros_like(corrred)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrred,cmap='flare',annot=True,linewidths=.1,square=True,mask=mask, vmax = 1, vmin = -1);
plt.title('Correlation heatmap red Wines',fontsize=15);
plt.show()
# Out:
# C:\Users\sfmol\AppData\Local\Temp\ipykernel_18864\1772406197.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrred = rw.corr()

# %%
ww = white_wine
corrwhite = ww.corr()
f,ax = plt.subplots(figsize=(15,14))
mask = np.zeros_like(corrwhite)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrwhite,cmap='GnBu',annot=True,linewidths=.1,square=True,mask=mask, vmax = 1, vmin = -1);
plt.title('Correlation heatmap white Wines',fontsize=15);
plt.show()
# Out:
# C:\Users\sfmol\AppData\Local\Temp\ipykernel_18864\3319248681.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrwhite = ww.corr()

# %%
# Create a single figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 8))

# Plot the heatmap for red wine in the first subplot
sns.heatmap(corrred, vmin=-1, vmax=1, annot=True, cmap='flare',
            annot_kws={'fontsize':8, 'fontweight':'bold'},
            square=True, ax=axes[0])
axes[0].set_title('Red Wine')

# Plot the heatmap for white wine in the second subplot
sns.heatmap(corrwhite, vmin=-1, vmax=1, annot=True, cmap='Greens',
            annot_kws={'fontsize':8, 'fontweight':'bold'},
            square=True, ax=axes[1])
axes[1].set_title('White Wine')

# Display the plot
plt.show()

# %%
sns.jointplot(data=red_wine, x="volatile acidity", y="alcohol", hue="quality")

# %%
sns.jointplot(data=red_wine, x="volatile acidity", y="alcohol")

# %%
sns.jointplot(data=red_wine, x="volatile acidity", y="alcohol", hue="quality", kind="kde")

# %%
sns.jointplot(data=red_wine, x="volatile acidity", y="alcohol", hue="quality_label", kind="kde", palette="magma")

# %% [markdown]
# ### *2 var:

# %%
sns.jointplot(data=red_wine, x="volatile acidity",y="quality", kind="reg")

# %%
sns.jointplot(
    data=red_wine, x="volatile acidity",y="quality",
    marker="+", s=100, marginal_kws=dict(bins=25, fill=False),
)

# %%
penguins = red_wine
g = sns.jointplot(data=penguins, x="quality", y="volatile acidity",
                  kind='hex', cmap="gnuplot", ratio=4,
                  marginal_ticks=False, marginal_kws=dict(bins=25, fill=False))

values = g.ax_joint.collections[0].get_array()
ind_max = values.argmax()
xy_max = g.ax_joint.collections[0].get_offsets()[ind_max]
g.ax_joint.text(xy_max[0], xy_max[1], f" Max: {values[ind_max]:.0f}\n x={xy_max[0]:.2f}\n y={xy_max[1]:.2f}",
                color='lime', ha='left', va='bottom', fontsize=14, fontweight='bold')
g.ax_joint.axvline(xy_max[0], color='red')
g.ax_joint.axhline(xy_max[1], color='red')
plt.tight_layout()
plt.show()

print(f"The highest bin contains {values[ind_max]:.0f} values")
print(f"  and has as center: x={xy_max[0]:.2f}, y={xy_max[1]:.2f}")
# Out:
# The highest bin contains 1170 values
#   and has as center: x=6.00, y=0.19

# %% [markdown]
# #### Crear en la matriz 3 columnas de correlaciones entre calidad vs alcohol, caliad vs volatile acidity y calidad vs sulphates (orden  decreciente) ver eventualmente como obtener matematicamente los valores max o min de correlaciones tipo ranking para determinar cual es la mejor combinatoria para calidad o "calidad_categories" vs las otras variables o tres o cuatro variables ... Como cambiar el codigo  como F2 pero de solamente una cell?
#
# #### Put both graphs side by side, how to replace all variables in only one cell?, make the relationship between quality and two or more variables. Evaluar las combinatorias estadisticas de 3 variables sin repetirse en un conjunto o universo de 12 elementos (combinatorias). Cuntas serían sólo por saber.
#
# #### *Revisar si hay datos duplicados
#
# #### red_wine.describe()
#
# #### *Raul: Cómo era eso de GitHub que dibujó para hacer codigo pero no subir cuando se trabaja en equipo?

# %% [markdown]
# ## Covariance

# %%
# Combine the two datasets into one
# wine = pd.concat([red_wine, white_wine], axis=0)

# Calculate the covariance between quality and volatile acidity
cov = np.cov(red_wine['volatile acidity'], red_wine['quality'])[0][1]

# Add the covariance value to a new column in the dataframe
red_wine.loc[:, 'volatile_acidity_quality_cov'] = cov

# Display the updated dataframe
print(red_wine.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label  volatile_acidity_quality_cov
# ...

# %% [markdown]
# ## Correlation

# %%
# Calculate the correlation coefficient between quality and volatile acidity
corr_coef = red_wine['quality'].corr(red_wine['volatile acidity'])

# Add the correlation coefficient value to a new column in the dataframe
red_wine.loc[:, 'quality_volatile_acidity_corr'] = corr_coef

# Display the updated dataframe
print(red_wine.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label  volatile_acidity_quality_cov  \
# ...

# %%
# Calculate the correlation coefficient between quality and volatile acidity
corr_coef = red_wine['volatile acidity'].corr(red_wine['quality'])

# Add the correlation coefficient value to a new column in the dataframe
red_wine.loc[:, 'volatile_acidity_quality_corr'] = corr_coef

# Display the updated dataframe
print(red_wine.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label  volatile_acidity_quality_cov  \
# ...

# %% [markdown]
# ### Summary of some entries

# %%
# white_wine.describe()

# "To display the names of all columns in Pandas:
# red_wine.columns

# Statistical parameters for only the 'alcohol' column in the 'red_wine' DataFrame:
# red_wine.describe()['alcohol']

# para crear la nueva columna quality_label en el DataFrame red_wine, usando la columna quality existente y la función lambda especificada:
# red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low' if value <= 5 else 'medium' if value <= 7 else 'high')

#To obtain the mean and standard deviation of the 'alcohol' column, you can use the following:
#print("Mean of the 'alcohol' column:", red_wine['alcohol'].mean())
# print("Standard Deviation 'alcohol'column:", red_wine['alcohol'].std())

# Describing both databases at once vertically
# pd.concat([red_wine.describe(), white_wine.describe()], axis=0, keys=["Red Wines Stats", "White Wines Stats"])

# Calculate the correlation coefficient between quality and volatile acidity
# corr_coef = red_wine['quality'].corr(red_wine['volatile acidity'])

# Add the correlation coefficient value to a new column in the dataframe
# red_wine.loc[:, 'quality_volatile_acidity_corr'] = corr_coef

# Drop the quality_volatile_acidity_corr column from the dataframe
#red_wine = red_wine.drop(columns=['quality_volatile_acidity_corr'])

# Display the updated dataframe
#print(wine.head())

# %% [markdown]
# ### *(to ask) Why the column 'quality_label' does not appear?

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity   citric acid  residual sugar  \
# count   16293.000000      16293.000000  16293.000000    16293.000000
# mean        6.998548          0.302735      0.327987        6.013319
# std         1.062734          0.133490      0.131462        4.970562
# min         3.800000          0.080000      0.000000        0.600000
# 25%         6.400000          0.220000      0.260000        1.800000
# 50%         6.800000          0.270000      0.310000        4.500000
# 75%         7.400000          0.350000      0.390000        9.100000
# max        15.900000          1.580000      1.660000       65.800000
#
#           chlorides  free sulfur dioxide  total sulfur dioxide       density  \
# count  16293.000000         16293.000000          16293.000000  16293.000000
# mean       0.049864            33.400908            129.342264      0.994294
# std        0.028312            17.463627             49.821497      0.003012
# ...

# %% [markdown]
# ### *(to ask) Why the columns 'quality_volatile_acidity_corr' and "volatile_acidity_quality_corr" now does not appear? Does it depend on the library command?

# %%
red_wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'quality_label',
#        'volatile_acidity_quality_cov', 'quality_volatile_acidity_corr',
#        'volatile_acidity_quality_corr'],
#       dtype='object')

# %%
 red_wine.describe()["density"]
# Out:
# count    16293.000000
# mean         0.994294
# std          0.003012
# min          0.987110
# 25%          0.991900
# 50%          0.994160
# 75%          0.996590
# max          1.038980
# Name: density, dtype: float64

# %%
from scipy import stats

F, p = stats.f_oneway(red_wine[red_wine['quality_label'] == 'low']['alcohol'],
red_wine[red_wine['quality_label'] == 'medium']['alcohol'],
red_wine[red_wine['quality_label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 from scipy import stats
#       3 F, p = stats.f_oneway(red_wine[red_wine['quality_label'] == 'low']['alcohol'],
#       4 red_wine[red_wine['quality_label'] == 'medium']['alcohol'],
#       5 red_wine[red_wine['quality_label'] == 'high']['alcohol'])
#       6 print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# ### Duplicates Red wine

# %%
# Check for duplicate rows
duplicates = red_wine.duplicated()

# Count the number of duplicate rows
num_duplicates = duplicates.sum()

# Print the result
if num_duplicates > 0:
    print(f'There are {num_duplicates} duplicate rows in the dataset')
else:
    print('There are no duplicate rows in the dataset')
# Out:
# There are 6075 duplicate rows in the dataset

# %% [markdown]
# ### Duplicates White wine

# %%
# Check for duplicate rows
duplicates = white_wine.duplicated()

# Count the number of duplicate rows
num_duplicates = duplicates.sum()

# Print the result
if num_duplicates > 0:
    print(f'There are {num_duplicates} duplicate rows in the dataset')
else:
    print('There are no duplicate rows in the dataset')
# Out:
# There are 937 duplicate rows in the dataset

# %% [markdown]
# #### Data frame without duplicates: Methods

# %% [markdown]
# import pandas as pd
#
# Load the red wines dataset
# red_wines = pd.read_csv('red_wines.csv')
#
# Drop duplicate rows based on all columns
# red_wines_unique = red_wines.drop_duplicates()
#
# Drop duplicate rows based on a subset of columns
# red_wines_unique_subset = red_wines.drop_duplicates(subset=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality'])
#
# Print the number of rows in the original and unique DataFrames
# print(f"Original DataFrame: {len(red_wines)} rows")
# print(f"Unique DataFrame: {len(red_wines_unique)} rows")
# print(f"Unique DataFrame (subset): {len(red_wines_unique_subset)} rows")

# %% [markdown]
# In this example, the drop_duplicates() method is used to create a new DataFrame without duplicate rows. The first call to drop_duplicates() drops all rows that have identical values in all columns, whereas the second call to drop_duplicates() drops rows that have identical values only in the specified subset of columns. The resulting DataFrames are stored in the variables red_wines_unique and red_wines_unique_subset, respectively. The len() function is used to print the number of rows in the original and unique DataFrames.

# %% [markdown]
# # Preparing the preliminary presentation

# %% [markdown]
# ### Red Wine´s data frame without duplicates: "red_wines_unique"

# %%
# Starting with the original red wine file
red_wine = pd.read_csv('winequality-red.csv',sep=';')

# Drop duplicate rows based on all columns
red_wines_unique = red_wine.drop_duplicates()

# Print the number of rows in the original and unique DataFrames
print(f"Original DataFrame: {len(red_wine)} rows")
print(f"Unique DataFrame: {len(red_wines_unique)} rows")
# Out:
# Original DataFrame: 1599 rows
# Unique DataFrame: 1359 rows

# %% [markdown]
# ### White Wine´s data frame without duplicates: "white_wines_unique"

# %%
# Starting with the original white wine file
white_wine = pd.read_csv('winequality-white.csv',sep=';')

# Drop duplicate rows based on all columns
white_wines_unique = white_wine.drop_duplicates()

# Print the number of rows in the original and unique DataFrames
print(f"Original DataFrame: {len(white_wine)} rows")
print(f"Unique DataFrame: {len(white_wines_unique)} rows")
# Out:
# Original DataFrame: 4898 rows
# Unique DataFrame: 3961 rows

# %%
red_wines_unique.shape
# Out:
# (1359, 12)

# %%
white_wines_unique.shape
# Out:
# (3961, 12)

# %% [markdown]
# ### "red_wines_unique": Adding quality_label

# %%
red_wines_unique['quality_label'] = red_wines_unique['quality'].apply(lambda value: 'low' if value <= 5 else 'medium' if value <= 7 else 'high')
# Out:
# C:\Users\sfmol\AppData\Local\Temp\ipykernel_8792\3875307082.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   red_wines_unique['quality_label'] = red_wines_unique['quality'].apply(lambda value: 'low' if value <= 5 else 'medium' if value <= 7 else 'high')

# %% [markdown]
# ### "white_wines_unique": Adding quality_label

# %%
white_wines_unique['quality_label'] = white_wines_unique['quality'].apply(lambda value: 'low' if value <= 5 else 'medium' if value <= 7 else 'high')
# Out:
# C:\Users\sfmol\AppData\Local\Temp\ipykernel_8792\3750431844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   white_wines_unique['quality_label'] = white_wines_unique['quality'].apply(lambda value: 'low' if value <= 5 else 'medium' if value <= 7 else 'high')

# %% [markdown]
# ### Describing both databases at once vertically

# %%
pd.concat([red_wines_unique.describe(), white_wines_unique.describe()], axis=0, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#                          fixed acidity  volatile acidity  citric acid  \
# Red Wines Stats   count    1359.000000       1359.000000  1359.000000
#                   mean        8.310596          0.529478     0.272333
#                   std         1.736990          0.183031     0.195537
#                   min         4.600000          0.120000     0.000000
#                   25%         7.100000          0.390000     0.090000
#                   50%         7.900000          0.520000     0.260000
#                   75%         9.200000          0.640000     0.430000
#                   max        15.900000          1.580000     1.000000
# White Wines Stats count    3961.000000       3961.000000  3961.000000
#                   mean        6.839346          0.280538     0.334332
#                   std         0.866860          0.103437     0.122446
#                   min         3.800000          0.080000     0.000000
# ...

# %% [markdown]
# # Checking the data again

# %%
# Check for empty or null values in the "quality" column
num_missing = red_wines_unique['quality'].isnull().sum()

# Print the result
if num_missing > 0:
    print(f'There are {num_missing} empty or null values in the "quality" column')
else:
    print('There are no empty or null values in the "quality" column')
# Out:
# There are no empty or null values in the "quality" column

# %%
# Check for empty or null values in the "quality" column
num_missing = white_wines_unique['quality'].isnull().sum()

# Print the result
if num_missing > 0:
    print(f'There are {num_missing} empty or null values in the "quality" column')
else:
    print('There are no empty or null values in the "quality" column')
# Out:
# There are no empty or null values in the "quality" column

# %%
red_wines_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1359 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
#  12  quality_label         1359 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 148.6+ KB

# %%
white_wines_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3961 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3961 non-null   float64
#  1   volatile acidity      3961 non-null   float64
#  2   citric acid           3961 non-null   float64
#  3   residual sugar        3961 non-null   float64
#  4   chlorides             3961 non-null   float64
#  5   free sulfur dioxide   3961 non-null   float64
#  6   total sulfur dioxide  3961 non-null   float64
#  7   density               3961 non-null   float64
#  8   pH                    3961 non-null   float64
#  9   sulphates             3961 non-null   float64
#  10  alcohol               3961 non-null   float64
#  11  quality               3961 non-null   int64
#  12  quality_label         3961 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 433.2+ KB

# %% [markdown]
# ### Comparing correlations between variables

# %%
red_unique_no_qualitylabel = red_wines_unique[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']]

corr_red = red_unique_no_qualitylabel.corr()

white_unique_no_qualitylabel = white_wines_unique[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']]

corr_white = white_unique_no_qualitylabel.corr()


# Create a single figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

# Plot the heatmap for red wine in the first subplot
sns.heatmap(corr_red, vmin=-1, vmax=1, annot=True, cmap='flare',
            annot_kws={'fontsize':9, 'fontweight':'bold'},
            square=True, ax=axes[0])
axes[0].set_title('Red Wine')

# Plot the heatmap for white wine in the second subplot
sns.heatmap(corr_white, vmin=-1, vmax=1, annot=True, cmap='Greens',
            annot_kws={'fontsize':9, 'fontweight':'bold'},
            square=True, ax=axes[1])
axes[1].set_title('White Wine')

rt = plt.suptitle('Red and White wine correlation', x=0.5, y=1.12, fontsize=20)

# Display the plot
plt.show()
